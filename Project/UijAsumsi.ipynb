# %%
import pyreadstat
from tabulate import tabulate

# Path to your .sav file
file_path = 'data2015_2017_log.sav'

# Read the .sav file
df, meta = pyreadstat.read_sav(file_path)

# Display the first few rows of the dataframe in tabulated format
print(tabulate(df.head(), headers='keys', tablefmt='grid'))
# Out:
# +----+--------+----------+---------+---------------+------------+-------------+------------+-------------------+----------------+
# |    |   Year |    PM2.5 |    PM10 |   TotalDeaths |   PMDeaths |   Log_PM2.5 |   Log_PM10 |   Log_TotalDeaths |   Log_PMDeaths |
# +====+========+==========+=========+===============+============+=============+============+===================+================+
# |  0 |   2015 | 21.79    | 32.415  |       42.2998 |    21.7861 |    1.33826  |    1.51075 |           1.62634 |        1.33818 |
# +----+--------+----------+---------+---------------+------------+-------------+------------+-------------------+----------------+
# |  1 |   2015 | 10.26    | 27.87   |       33.0869 |    29.1591 |    1.01115  |    1.44514 |           1.51966 |        1.46477 |
# +----+--------+----------+---------+---------------+------------+-------------+------------+-------------------+----------------+
# |  2 |   2015 |  7.07842 | 17.7747 |       11.2768 |    10.7021 |    0.849936 |    1.2498  |           1.05219 |        1.02947 |
# +----+--------+----------+---------+---------------+------------+-------------+------------+-------------------+----------------+
# |  3 |   2015 | 13.6445  | 18.8565 |       18.8578 |    16.741  |    1.13496  |    1.27546 |           1.27549 |        1.22378 |
# +----+--------+----------+---------+---------------+------------+-------------+------------+-------------------+----------------+
# |  4 |   2015 | 12.6217  | 20.4832 |       20.4765 |    18.3594 |    1.10112  |    1.3114  |           1.31126 |        1.26386 |
# +----+--------+----------+---------+---------------+------------+-------------+------------+-------------------+----------------+

# %%
pm25     = df['PM2.5']
pm10     = df['PM10']
log_pm25 = df['Log_PM2.5']
log_pm10 = df['Log_PM10']
